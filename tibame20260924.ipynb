# %% [markdown]
# <a href="https://colab.research.google.com/github/NNBtw/tibame20260910/blob/main/tibame20260924.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# main.py
import pygame as pg
import random
import constants as const

#pygame初始化
pg.init()

# --- 字型 ---
def get_font(size):
    for f in ['microsoftjhenghei', 'simhei', 'stheitirelight']:
        if f in pg.font.get_fonts():
            return pg.font.SysFont(f, size)
    return pg.font.SysFont(None, size)

# 字體沒用到(順便給你而已)
FONT_UI = get_font(32)
col, row = const.NUM_COLS, const.NUM_ROWS
inter = const.INTER
width, height = col * inter, row * inter
# 產生視窗
screen = pg.display.set_mode((width, height))
# 設定遊戲標題
pg.display.set_caption("貪食蛇")

snake = []
# TODO: 0924_1
direction = const.RIGHT
apples = set()
def reset():
    # TODO: 0924_1
    global snake, direction
    snake = [(0, 2), (0, 1), (0, 0)]
    refill_apples()
    # TODO: 0924_1
    direction = const.RIGHT

def refill_apples(count=10):
    global apples, snake
    while len(apples) < count:
        i = random.randint(0, row-1)
        j = random.randint(0, col-1)
        # 如果蘋果再蛇的身體裡面也是不對的
        if not (i, j) in snake:
            apples.add((i, j))

# 把我們邏輯的(i, j) -> UI(x, y)左上角
def ij_to_xy_ul(i, j):
    x = j * inter
    y = i * inter
    return (x, y)

def check_death():
    # TODO: 0924_1
    hi, hj = snake[0]
    if 0 <= hi < row and 0 <= hj < col:
        # 活
        return False
    # 死
    return True

# 只管蛇的邏輯(狀態): 你絕對不會看到我在update裡做任何畫面的更新
def update():
    # TODO: 0924_1
    # 根據方向(direction)做出更新
    hi, hj = snake[0]
    # 蛇的頭要根據你的方向往前進 insert(0, 座標tuple)
    if direction == const.RIGHT:
        hj = hj + 1
    elif direction == const.LEFT:
        hj = hj - 1
    elif direction == const.DOWN:
        hi = hi + 1
    elif direction == const.UP:
        hi = hi - 1
    snake.insert(0, (hi, hj))
    # 蛇的尾巴方兩種狀況
    # CASE 1. 蛇頭吃到蘋果, 尾巴不用丟掉(變長), 你要refill apples
    if (hi, hj) in apples:
        apples.discard((hi, hj))
        refill_apples()
    # CASE 2. 蛇頭沒吃到蘋果, 尾巴要丟掉 pop()
    else:
        snake.pop()

# 只管畫面: 你絕對不會看到我在draw裡做任何邏輯的更新
# 更新畫面: 直接把所有東西重畫, 圖層(一層疊一層)
def draw():
    # 準備第一個圖層
    bg = pg.Surface(screen.get_size())
    # 把畫布填滿某個顏色
    bg.fill(const.COLOR_BG)

    # pygame.draw.line(畫布, 顏色, (x坐標1, y坐標1), (x坐標2, y坐標2), 線寬)
    for i in range(col+1):
        pg.draw.line(bg,
                     const.COLOR_LINE,
                     (i * inter, 0),
                     (i * inter, height),
                     1)

    for i in range(row+1):
        pg.draw.line(bg,
                     const.COLOR_LINE,
                     (0, i * inter),
                     (width, i * inter),
                     1)

    # 劃出我的蛇
    for (i, j) in snake:
        x, y = ij_to_xy_ul(i, j)
        pg.draw.rect(bg,
                     const.COLOR_SNAKE_BODY,
                     (x, y, inter, inter),
                     0)
    # 補畫一下頭
    i, j = snake[0]
    x, y = ij_to_xy_ul(i, j)
    pg.draw.rect(bg,
                 const.COLOR_SNAKE_HEAD,
                 (x, y, inter, inter),
                 0)
    for (i, j) in apples:
        x, y = ij_to_xy_ul(i, j)
        pg.draw.rect(bg,
                     const.COLOR_APPLE,
                     (x, y, inter, inter),
                     0)

    # 你要把圖層放到上一層
    screen.blit(bg, (0, 0))
    # 對畫面進行更新(才會真的秀出來)
    pg.display.update()

reset()
draw()
# 1. 建立時鐘物件
clock = pg.time.Clock()
FPS = 10  # 設定每秒最高更新 10 次
# 建立一個永不結束的迴圈(遊戲才不會結束)
running = True
while running:
    # 收取你的遊戲任何事件(滑鼠點擊/鍵盤按鈕...)
    for event in pg.event.get():
        # 偵測鍵盤按下某個按鍵以後放掉的動作
        if event.type == pg.KEYDOWN:
            # 如果需要判斷具體是哪一個：
            # TODO: 0924_1
            if event.key == pg.K_UP:
                if not direction == const.DOWN:
                    direction = const.UP
            elif event.key == pg.K_DOWN:
                if not direction == const.UP:
                    direction = const.DOWN
            elif event.key == pg.K_LEFT:
                if not direction == const.RIGHT:
                    direction = const.LEFT
            elif event.key == pg.K_RIGHT:
                if not direction == const.LEFT:
                    direction = const.RIGHT
        # 如果收到的事件是按視窗的x
        if event.type == pg.QUIT:
            # 迴圈就會變成while False
            running = False
    update()
    draw()
    if check_death():
        reset()
    # 會幫你算這迴圈在這裡停幾秒再進下一次
    clock.tick(FPS)

pg.quit()

# %%
# constants.py
# constants.py
COLOR_BG = (235, 204, 167)
COLOR_LINE = (100, 100, 100)
COLOR_SNAKE_BODY = (242, 80, 237)
COLOR_SNAKE_HEAD = (252, 210, 251)
COLOR_APPLE = (255, 0, 0)

RIGHT = 0
LEFT = 1
DOWN = 2
UP = 3

NUM_COLS = 30
NUM_ROWS = 30

INTER = 20

# %%
# 應要求, 左右要穿過去, 撞到自己要死掉, 死掉出現再隨機位置
# main.py
import pygame as pg
import random
import constants as const

#pygame初始化
pg.init()

# --- 字型 ---
def get_font(size):
    for f in ['microsoftjhenghei', 'simhei', 'stheitirelight']:
        if f in pg.font.get_fonts():
            return pg.font.SysFont(f, size)
    return pg.font.SysFont(None, size)

# 字體沒用到(順便給你而已)
FONT_UI = get_font(32)
col, row = const.NUM_COLS, const.NUM_ROWS
inter = const.INTER
width, height = col * inter, row * inter
# 產生視窗
screen = pg.display.set_mode((width, height))
# 設定遊戲標題
pg.display.set_caption("貪食蛇")

snake = []
# TODO: 0924_1
direction = const.RIGHT
apples = set()
def reset():
    # TODO: 0924_1
    global snake, direction
    # 頭, 會隨機, i的任意位置, j 2 以後開始
    hi, hj = random.randint(0, row), random.randint(2, col)
    snake = [(hi, hj), (hi, hj-1), (hi, hj-2)]
    refill_apples()
    # TODO: 0924_1
    direction = const.RIGHT

def refill_apples(count=10):
    global apples, snake
    while len(apples) < count:
        i = random.randint(0, row-1)
        j = random.randint(0, col-1)
        # 如果蘋果再蛇的身體裡面也是不對的
        if not (i, j) in snake:
            apples.add((i, j))

# 把我們邏輯的(i, j) -> UI(x, y)左上角
def ij_to_xy_ul(i, j):
    x = j * inter
    y = i * inter
    return (x, y)

def check_death():
    # TODO: 0924_1
    hi, hj = snake[0]
    if 0 <= hi < row:
        # TODO: +頭碰到身體
        if (hi, hj) in snake[1:]:
            return True
        # 活
        else:
            return False
    # 死
    return True

# 只管蛇的邏輯(狀態): 你絕對不會看到我在update裡做任何畫面的更新
def update():
    # TODO: 0924_1
    # 根據方向(direction)做出更新
    hi, hj = snake[0]
    # 蛇的頭要根據你的方向往前進 insert(0, 座標tuple)
    if direction == const.RIGHT:
        hj = hj + 1
    elif direction == const.LEFT:
        hj = hj - 1
    elif direction == const.DOWN:
        hi = hi + 1
    elif direction == const.UP:
        hi = hi - 1
    # 因為我想循環
    hj = hj % col
    snake.insert(0, (hi, hj))
    # 蛇的尾巴方兩種狀況
    # CASE 1. 蛇頭吃到蘋果, 尾巴不用丟掉(變長), 你要refill apples
    if (hi, hj) in apples:
        apples.discard((hi, hj))
        refill_apples()
    # CASE 2. 蛇頭沒吃到蘋果, 尾巴要丟掉 pop()
    else:
        snake.pop()

# 只管畫面: 你絕對不會看到我在draw裡做任何邏輯的更新
# 更新畫面: 直接把所有東西重畫, 圖層(一層疊一層)
def draw():
    # 準備第一個圖層
    bg = pg.Surface(screen.get_size())
    # 把畫布填滿某個顏色
    bg.fill(const.COLOR_BG)

    # pygame.draw.line(畫布, 顏色, (x坐標1, y坐標1), (x坐標2, y坐標2), 線寬)
    for i in range(col+1):
        pg.draw.line(bg,
                     const.COLOR_LINE,
                     (i * inter, 0),
                     (i * inter, height),
                     1)

    for i in range(row+1):
        pg.draw.line(bg,
                     const.COLOR_LINE,
                     (0, i * inter),
                     (width, i * inter),
                     1)

    # 劃出我的蛇
    for (i, j) in snake:
        x, y = ij_to_xy_ul(i, j)
        pg.draw.rect(bg,
                     const.COLOR_SNAKE_BODY,
                     (x, y, inter, inter),
                     0)
    # 補畫一下頭
    i, j = snake[0]
    x, y = ij_to_xy_ul(i, j)
    pg.draw.rect(bg,
                 const.COLOR_SNAKE_HEAD,
                 (x, y, inter, inter),
                 0)
    for (i, j) in apples:
        x, y = ij_to_xy_ul(i, j)
        pg.draw.rect(bg,
                     const.COLOR_APPLE,
                     (x, y, inter, inter),
                     0)

    # 你要把圖層放到上一層
    screen.blit(bg, (0, 0))
    # 對畫面進行更新(才會真的秀出來)
    pg.display.update()

reset()
draw()
# 1. 建立時鐘物件
clock = pg.time.Clock()
FPS = 10  # 設定每秒最高更新 10 次
# 建立一個永不結束的迴圈(遊戲才不會結束)
running = True
while running:
    # 收取你的遊戲任何事件(滑鼠點擊/鍵盤按鈕...)
    for event in pg.event.get():
        # 偵測鍵盤按下某個按鍵以後放掉的動作
        if event.type == pg.KEYDOWN:
            # 如果需要判斷具體是哪一個：
            # TODO: 0924_1
            if event.key == pg.K_UP:
                if not direction == const.DOWN:
                    direction = const.UP
            elif event.key == pg.K_DOWN:
                if not direction == const.UP:
                    direction = const.DOWN
            elif event.key == pg.K_LEFT:
                if not direction == const.RIGHT:
                    direction = const.LEFT
            elif event.key == pg.K_RIGHT:
                if not direction == const.LEFT:
                    direction = const.RIGHT
        # 如果收到的事件是按視窗的x
        if event.type == pg.QUIT:
            # 迴圈就會變成while False
            running = False
    update()
    draw()
    if check_death():
        reset()
    # 會幫你算這迴圈在這裡停幾秒再進下一次
    clock.tick(FPS)

pg.quit()
