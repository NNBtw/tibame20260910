# %% [markdown]
# <a href="https://colab.research.google.com/github/NNBtw/tibame20260910/blob/main/tibame20260924_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request as req

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=38250&geo=TW%2CHK"
f = req.urlopen(url)
content = f.read()
# loads: bytes型態->list/dic型態
content = json.loads(content)
# print(type(content))
# [彈幕{}, 彈幕{}...]
danmus = content["data"]["danmu"]
for d in danmus:
    print(d["userid"], d["text"])
# Out:
# andy475713 1
# tcg19648 2024.6.23簽
# shackle9487 簽🌭️
# naiyu0429 2024/7/3冬雪簽
# gtkl20050 為何一直沒法看
# robloxaron 2025/8/6首簽!!!
# FeiFei88 2025／8／24
# efg130 20250802
# star112999 20240821 我來啦
# cmh0326 2024/7/27 簽 (剛又刷一次刀匠
# lkjh4128 台中代表簽
# Cwy0831 Sign
# f82726 不知道幾刷簽
# cpz0426 20262/28簽到
# caizhenlzz72 2025/8/1簽
# po971030 2024.08.04
# baseball2470 簽🌭️
# brightwinnn 簽嗚嗚嗚嗚
# lspss93011 2025/07/07小史簽
# zenyu98 神作留名
# cfs10519 簽 2024/8/21
# Jayabby666 2024.06.11簽ʕ´•ᴥ•`ʔ
# nini1001208 必須簽！
# poopoo9999 あります平城山ならゆ
# fsh975321 俺沒偷梅吃
# Ifffhftg 哈哈
# wrxmars 2025.8.11等無限城第二部 簽
# Kakashi09182 神作簽簽簽！！！
# chachamashum 簽！！！！！
# yinyinoby 2026/1/17
# supreme888 2025/8/13簽 ε٩(๑> ₃ <)۶з
# Ajasmine5678 2024/6/11
# hsiao700915 2025/2/6
# xin54081 2025 8／25簽！
# pinhuah30 ♡
# fgbg32112 2025/02/04 簽
# s206179 簽
# J50223 有夠好看!!
# q06974520 簽(⁠⁰⁠▿⁠⁰⁠)⁠
# milly0411 20250805 LLL
# kang520000 終於來了   簽😍
# b4y9vtf99 2025 2刷簽
# tsung3689 2025/8/13 簽~
# xhbihwsxbi 2025/12/7簽（剛刷完刀匠村）
# bluesezero 2024.08.17簽
# ...

# %% [markdown]
# - 標準格式
#     - JSON格式: list+dict
#     - CSV格式(Comma-Separtated Values)
#         - 姓名,身高
#         - Elwing,175
#         - "Elwing, Mr. Chou",180

# %%
import json
import urllib.request as req
import pandas as pd

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=38250&geo=TW%2CHK"
f = req.urlopen(url)
content = f.read()
content = json.loads(content)
danmus = content["data"]["danmu"]
# pandas: DataFrame表格型態
df = pd.DataFrame(danmus)
df.to_csv("danmu.csv", encoding="utf-8", index=False)
df
# Out:
#                    text    color  size  position   time        sn       userid
# 0                     1  #FFFFFF     1         0      0  39929764   andy475713
# 1            2024.6.23簽  #FFFFFF     1         0      0  40108494     tcg19648
# 2                   簽🌭️  #FDE53D     1         0      0  40273436  shackle9487
# 3           2024/7/3冬雪簽  #FDE53D     2         0      0  40292119    naiyu0429
# 4               為何一直沒法看  #FFFFFF     1         0      0  42343409    gtkl20050
# ...                 ...      ...   ...       ...    ...       ...          ...
# 2996  這邊也好可愛😍 根本聖人狀態😍😍😍  #FFFFFF     0         2  29130  45144557     CCLEMONN
# 2997                 )(  #FF9496     2         2  29225  45144563     CCLEMONN
# 2998             大大大大大大  #B538FA     2         0  29231  39879325    FAQYEE123
# 2999         小學生可看不了呢老人  #FF0026     2         2  29389  46818174   h4kmg6snf2
# 3000        2025.7.29 *  #FFFFFF     1         0  29399  45902639      s935602
#
# [3001 rows x 7 columns]

# %%
data = [
    {"name":"Elwing", "height":175},
    {"name":"Elwing, Mr. Chou", "height":180}
]
pd.DataFrame(data)
# Out:
#                name  height
# 0            Elwing     175
# 1  Elwing, Mr. Chou     180

# %% [markdown]
# - pandas兩大操作
#     - 過濾: 準備一個跟你資料筆數依樣多的True(留下)/False(刪除)
#     - 轉換: 準備一個函式, 參數就是原始資料,

# %%
# demo: 過濾(filter(fil))
fil = [True, False, True]
df.head(3)[fil]
# Out:
#   text    color  size  position  time        sn       userid
# 0    1  #FFFFFF     1         0     0  39929764   andy475713
# 2  簽🌭️  #FDE53D     1         0     0  40273436  shackle9487

# %%
s = "andy475713"
df["userid"] == s
df.head(3)[fil]
# Out:
#   text    color  size  position  time        sn       userid
# 0    1  #FFFFFF     1         0     0  39929764   andy475713
# 2  簽🌭️  #FDE53D     1         0     0  40273436  shackle9487

# %%
# demo: 轉換
# time
def func(n):
    return n + 100
df["time"].apply(func)
# Out:
# 0         100
# 1         100
# 2         100
# 3         100
# 4         100
#         ...
# 2996    29230
# 2997    29325
# 2998    29331
# 2999    29489
# 3000    29499
# Name: time, Length: 3001, dtype: int64

# %%
# demo: 轉換
# color(HEX色碼->RGB code)
def func(s):
    s = s.replace("#", "")
    r, g, b = s[:2], s[2:4], s[4:]
    r, g, b = int(r, 16), int(g, 16), int(b, 16)
    return(r, g, b)
df["color"].apply(func)
# Out:
# 0       (255, 255, 255)
# 1       (255, 255, 255)
# 2        (253, 229, 61)
# 3        (253, 229, 61)
# 4       (255, 255, 255)
#              ...
# 2996    (255, 255, 255)
# 2997    (255, 148, 150)
# 2998     (181, 56, 250)
# 2999       (255, 0, 38)
# 3000    (255, 255, 255)
# Name: color, Length: 3001, dtype: object
