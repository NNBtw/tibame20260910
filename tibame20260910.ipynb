# %% [markdown]
# <a href="https://colab.research.google.com/github/NNBtw/tibame20260910/blob/main/tibame20260910.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - 文字使用的 markdown 語法
# - 支援 Latex Math
#     - 特殊符號 \ 開始
#     - 數學裡面 () -> {}
#     - $ area = \frac{1}{2} \pi R^2 $

# %% [markdown]
# - 演算法
#     - 不過就是想法(解題思路)
# - 完全平方日: 把日期表示數字以後, 他開根號為整數
#     - 從20241001開始往後數出十個完全平方日
#     - 20241001 = 4499 x 4499
#     - 20720704 = 4552 x 4552
#     - 你如果是使用紙筆計算機, 你如何數出十個
#         - 想法1: 每一個日期開根號, 看看是否為整數
#             - 20241001 ^ 0.5 = 4499
#             - 20241002 ^ 0.5 = 4499.0001(X)
#         - 想法2: 把每一個數字做平方, 看看是否可以當一個日期
#             - 4499 x 4499 = 20241001
#             - 4500 x 4500 = 20250000(X)
#     - 判斷兩個想法哪個比較好
#         - 想法1. 找到下一個你要花幾次
#             - 2070/07/04 - 2024/10/01 = 49年 * 365 = 17885(次)
#         - 想法2.
#             - 4552 - 4499 = 53(次)
#         - 你這兩個想法差距約300倍(17885 / 53)
#     - 兩個都做, 先從想法2開始
#         - 檢查每一個日期是否合理
#          - 年: > 0
#          - 月份: 12 >= >= 1
#          - 日:
#             - 每月份的日不一樣
#             - 閏年: 先來解決

# %%
# 2000 O
# 1800 X
# 1796 O
# 1795 X
year = 2000

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("O")
        else:
            print("X")
    else:
        print("O")
else:
    print("X")
# Out:
# O

# %%
year = 2000
if year % 400 == 0:
    print("O")
elif year % 100 == 0:
    print("X")
elif year % 4 == 0:
    print("O")
else:
    print("X")
